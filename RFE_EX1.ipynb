# %%
pip install pydicom
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pydicom


dcm_file = pydicom.dcmread("C:/Users/INDRANUJ/Desktop/000002.dcm")

# %%
dcm_file
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 196
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.1079.4008.949752002710420507972525362130
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.35'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPO']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# ...

# %%
dcm_file.PatientName
# Out:
# 'TCGA-G3-AAV5'

# %%
dcm_file.PatientName='xxxxx'

# %%
dcm_file.PatientName
# Out:
# 'xxxxx'

# %%
dcm_file.PatientBirthDate='xxxxx'

# %%
dcm_file.PatientSex='xxxxx'

# %%
dcm_file.PatientAge='xxxxx'

# %%
dcm_file.save_as('C:/Users/INDRANUJ/Desktop/'+'new'+'.dcm')

# %%
import pydicom


edited_dcm_file = pydicom.dcmread("C:/Users/INDRANUJ/Desktop/new.dcm")

# %%
edited_dcm_file
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 196
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.1079.4008.949752002710420507972525362130
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.35'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPO']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# ...

# %% [markdown]
# ![aaa.png](attachment:aaa.png)
